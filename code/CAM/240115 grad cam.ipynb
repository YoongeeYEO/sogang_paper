# %%
pwd
# Out:
# '/content'

# %%
# !git clone https://github.com/monjurulkarim/crack-localization.git
# Out:
# Cloning into 'crack-localization'...
# remote: Enumerating objects: 1454, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 1454 (delta 53), reused 93 (delta 52), pack-reused 1358
# Receiving objects: 100% (1454/1454), 91.74 MiB | 25.76 MiB/s, done.
# Resolving deltas: 100% (64/64), done.

# %%
# !pip install grad-cam
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 28.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for grad-cam: filename=grad_cam-1.5.0-py3-none-any.whl size=38070 sha256=ebc3c099e0a0394af88da0de128fd490f158d3922a6d880a7bc6752efce15376
#   Stored in directory: /root/.cache/pip/wheels/5b/e5/3d/8548241d5cffe53ad1476c566a61ad9bf09cc61a9430f09726
# Successfully built grad-cam
# ...

# %%
# !python3 /content/crack-localization/inference.py --type Positive
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Traceback (most recent call last):
#   File "/content/crack-localization/inference.py", line 89, in <module>
#     inference()
#   File "/content/crack-localization/inference.py", line 68, in inference
#     model.load_state_dict(torch.load('/content/crack-localization/snapshot/crack_model.pth'))
# ...

# %%
# !git clone https://github.com/dlr-wf/explainable-crack-tip-detection.git
# Out:
# Cloning into 'explainable-crack-tip-detection'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 73 (delta 21), reused 61 (delta 15), pack-reused 0
# Receiving objects: 100% (73/73), 363.61 KiB | 10.39 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
# !pip install -r /content/explainable-crack-tip-detection/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 18.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 MB 9.3 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement torch==1.7.1 (from versions: 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2)
# ERROR: No matching distribution found for torch==1.7.1
